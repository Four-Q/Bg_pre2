# %% [markdown]
# # Generate features by composition

# %%
import pandas as pd

# get data of mp/exp from the file 
mp_df = pd.read_csv("./Data/composition_data/mp_band_gap.csv")
exp_df = pd.read_csv("./Data/composition_data/exp_band_gap.csv")

# %%
mp_df.shape, exp_df.shape
# Out:
# ((10342, 2), (3130, 2))

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### 1. 基于元素组成进行特征化

# %%
# Change the name of composition column
mp_df.rename(columns={'composition': 'composition_str'}, inplace=True)
exp_df.rename(columns={'composition': 'composition_str'}, inplace=True)

# %%
mp_df.head()
# Out:
#   composition_str  band_gap
# 0         Ac16S24    2.2962
# 1       Ac1Ag1Te2    0.0794
# 2        Ac1Cr1O3    2.0031
# 3        Ac1Fe1O3    0.9888
# 4        Ac1Ga1O3    2.8959

# %%
# transform the composition_str column to composition column
from matminer.featurizers.conversions import StrToComposition

stc = StrToComposition(target_col_id='composition')
mp_df = stc.featurize_dataframe(mp_df, col_id="composition_str", pbar=True)
# Out:
# StrToComposition:   0%|          | 0/10342 [00:00<?, ?it/s]

# %%
exp_df = stc.featurize_dataframe(exp_df, col_id="composition_str", pbar=True)
# Out:
# StrToComposition:   0%|          | 0/3130 [00:00<?, ?it/s]

# %%
mp_df.head()
# Out:
#   composition_str  band_gap   composition
# 0         Ac16S24    2.2962       (Ac, S)
# 1       Ac1Ag1Te2    0.0794  (Ac, Ag, Te)
# 2        Ac1Cr1O3    2.0031   (Ac, Cr, O)
# 3        Ac1Fe1O3    0.9888   (Ac, Fe, O)
# 4        Ac1Ga1O3    2.8959   (Ac, Ga, O)

# %%
exp_df.head()
# Out:
#   composition_str  band_gap   composition
# 0   Hg0.7Cd0.3Te1      0.35  (Hg, Cd, Te)
# 1           Lu1P1      1.30       (Lu, P)
# 2       Cu3Sb1Se4      0.40  (Cu, Sb, Se)
# 3          Pt1Sb2      0.08      (Pt, Sb)
# 4        Zn1In2S4      2.68   (Zn, In, S)

# %%
# composition-based features
from matminer.featurizers.composition import ElementProperty
# 某些元素不存在"BulkModulus1"特征，我们不使用该特征
# 总共43个特征，6个统计量， 即43*6=258个特征
features=["Number","AtomicRadius","AtomicVolume","AtomicWeight","MolarVolume","SpaceGroupNumber","CovalentRadius","Density",
          "n_ws^third","Column","Electronegativity","ElectronAffinity","FirstIonizationEnergy","phi",
          "DipolePolarizability","Polarizability","BoilingT","MeltingT","ThermalConductivity","LogThermalConductivity",
          "HeatVaporization","HeatFusion","FusionEnthalpy","GSbandgap","GSenergy_pa","GSestBCClatcnt","GSestFCClatcnt","GSvolume_pa",
          "GSmagmom","NUnfilled","NValence","NdUnfilled","NdValence","NfUnfilled","NfValence","NpUnfilled","NpValence","NsUnfilled",
          "NsValence","ZungerPP-r_p","ZungerPP-r_pi","ZungerPP-r_s","ZungerPP-r_sigma"]
stats = ["minimum", "maximum", "mean", "avg_dev", "range", "mode"] 

featurizer = ElementProperty(data_source='magpie', features=features, stats=stats) 	# extracting features from a predefined database， e.g. magpie, jarvis, etc.
mp_featurized_df = featurizer.featurize_dataframe(mp_df, col_id='composition')
# Out:
# /home/codespace/.python/current/lib/python3.12/site-packages/matminer/utils/data.py:326: UserWarning: MagpieData(impute_nan=False):
# In a future release, impute_nan will be set to True by default.
#                     This means that features that are missing or are NaNs for elements
#                     from the data source will be replaced by the average of that value
#                     over the available elements.
#                     This avoids NaNs after featurization that are often replaced by
#                     dataset-dependent averages.
#   warnings.warn(f"{self.__class__.__name__}(impute_nan=False):\n" + IMPUTE_NAN_WARNING)
# ElementProperty:   0%|          | 0/10342 [00:00<?, ?it/s]

# %%
mp_featurized_df.head()
# Out:
#   composition_str  band_gap   composition  MagpieData minimum Number  \
# 0         Ac16S24    2.2962       (Ac, S)                       16.0
# 1       Ac1Ag1Te2    0.0794  (Ac, Ag, Te)                       47.0
# 2        Ac1Cr1O3    2.0031   (Ac, Cr, O)                        8.0
# 3        Ac1Fe1O3    0.9888   (Ac, Fe, O)                        8.0
# 4        Ac1Ga1O3    2.8959   (Ac, Ga, O)                        8.0
#
#    MagpieData maximum Number  MagpieData mean Number  \
# 0                       89.0                    45.2
# 1                       89.0                    60.0
# 2                       89.0                    27.4
# 3                       89.0                    27.8
# 4                       89.0                    28.8
#
#    MagpieData avg_dev Number  MagpieData range Number  MagpieData mode Number  \
# 0                      35.04                     73.0                    16.0
# 1                      14.50                     42.0                    52.0
# 2                      24.64                     81.0                     8.0
# 3                      24.48                     81.0                     8.0
# 4                      24.96                     81.0                     8.0
#
#    MagpieData minimum AtomicRadius  ...  MagpieData mean ZungerPP-r_s  \
# 0                              1.0  ...                           NaN
# 1                              1.4  ...                           NaN
# 2                              0.6  ...                           NaN
# 3                              0.6  ...                           NaN
# 4                              0.6  ...                           NaN
#
#    MagpieData avg_dev ZungerPP-r_s  MagpieData range ZungerPP-r_s  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#    MagpieData mode ZungerPP-r_s  MagpieData minimum ZungerPP-r_sigma  \
# 0                         0.540                                1.100
# 1                         0.790                                1.670
# 2                         0.285                                0.465
# 3                         0.285                                0.465
# 4                         0.285                                0.465
#
#    MagpieData maximum ZungerPP-r_sigma  MagpieData mean ZungerPP-r_sigma  \
# 0                                 3.12                           1.90800
# 1                                 3.12                           2.20875
# 2                                 3.12                           1.39100
# 3                                 3.12                           1.32500
# 4                                 3.12                           1.24200
#
#    MagpieData avg_dev ZungerPP-r_sigma  MagpieData range ZungerPP-r_sigma  \
# 0                              0.96960                              2.020
# 1                              0.53875                              1.450
# 2                              1.11120                              2.655
# 3                              1.03200                              2.655
# 4                              0.93240                              2.655
#
#    MagpieData mode ZungerPP-r_sigma
# 0                             1.100
# 1                             1.670
# 2                             0.465
# 3                             0.465
# 4                             0.465
#
# [5 rows x 261 columns]

# %%
exp_featurized_df = featurizer.featurize_dataframe(exp_df, col_id='composition')
exp_featurized_df.head()
# Out:
# ElementProperty:   0%|          | 0/3130 [00:00<?, ?it/s]
#   composition_str  band_gap   composition  MagpieData minimum Number  \
# 0   Hg0.7Cd0.3Te1      0.35  (Hg, Cd, Te)                       48.0
# 1           Lu1P1      1.30       (Lu, P)                       15.0
# 2       Cu3Sb1Se4      0.40  (Cu, Sb, Se)                       29.0
# 3          Pt1Sb2      0.08      (Pt, Sb)                       51.0
# 4        Zn1In2S4      2.68   (Zn, In, S)                       16.0
#
#    MagpieData maximum Number  MagpieData mean Number  \
# 0                       80.0               61.200000
# 1                       71.0               43.000000
# 2                       51.0               34.250000
# 3                       78.0               60.000000
# 4                       49.0               27.428571
#
#    MagpieData avg_dev Number  MagpieData range Number  MagpieData mode Number  \
# 0                  13.160000                     32.0                    52.0
# 1                  28.000000                     56.0                    15.0
# 2                   4.187500                     22.0                    34.0
# 3                  12.000000                     27.0                    51.0
# 4                  13.061224                     33.0                    16.0
#
#    MagpieData minimum AtomicRadius  ...  MagpieData mean ZungerPP-r_s  \
# 0                             1.40  ...                      0.917250
# 1                             1.00  ...                           NaN
# 2                             1.15  ...                      0.741250
# 3                             1.35  ...                      0.966667
# 4                             1.00  ...                      0.694286
#
#    MagpieData avg_dev ZungerPP-r_s  MagpieData range ZungerPP-r_s  \
# 0                         0.127250                          0.280
# 1                              NaN                            NaN
# 2                         0.126250                          0.265
# 3                         0.182222                          0.410
# 4                         0.176327                          0.400
#
#    MagpieData mode ZungerPP-r_s  MagpieData minimum ZungerPP-r_sigma  \
# 0                         0.790                                1.670
# 1                           NaN                                1.240
# 2                         0.615                                1.285
# 3                         0.830                                1.765
# 4                         0.540                                1.100
#
#    MagpieData maximum ZungerPP-r_sigma  MagpieData mean ZungerPP-r_sigma  \
# 0                                 2.41                          2.010750
# 1                                 3.37                          2.305000
# 2                                 2.04                          1.628125
# 3                                 2.70                          2.076667
# 4                                 2.05                          1.482857
#
#    MagpieData avg_dev ZungerPP-r_sigma  MagpieData range ZungerPP-r_sigma  \
# 0                             0.340750                              0.740
# 1                             1.065000                              2.130
# 2                             0.343125                              0.755
# 3                             0.415556                              0.935
# 4                             0.437551                              0.950
#
#    MagpieData mode ZungerPP-r_sigma
# 0                             1.670
# 1                             1.240
# 2                             1.285
# 3                             1.765
# 4                             1.100
#
# [5 rows x 261 columns]

# %% [markdown]
# #### Nan值处理

# %%
# 查看Nan值超过10%的特征
mp_nan = mp_featurized_df.isna().sum() / len(mp_featurized_df)
mp_nan = mp_nan[mp_nan > 0.1]
mp_nan = mp_nan.index.tolist()
mp_nan
# Out:
# ['MagpieData minimum n_ws^third',
#  'MagpieData maximum n_ws^third',
#  'MagpieData mean n_ws^third',
#  'MagpieData avg_dev n_ws^third',
#  'MagpieData range n_ws^third',
#  'MagpieData mode n_ws^third',
#  'MagpieData minimum phi',
#  'MagpieData maximum phi',
#  'MagpieData mean phi',
#  'MagpieData avg_dev phi',
#  'MagpieData range phi',
#  'MagpieData mode phi',
#  'MagpieData minimum ZungerPP-r_p',
#  'MagpieData maximum ZungerPP-r_p',
#  'MagpieData mean ZungerPP-r_p',
#  'MagpieData avg_dev ZungerPP-r_p',
#  'MagpieData range ZungerPP-r_p',
#  'MagpieData minimum ZungerPP-r_pi',
#  'MagpieData maximum ZungerPP-r_pi',
#  'MagpieData mean ZungerPP-r_pi',
#  'MagpieData avg_dev ZungerPP-r_pi',
#  'MagpieData range ZungerPP-r_pi',
#  'MagpieData minimum ZungerPP-r_s',
#  'MagpieData maximum ZungerPP-r_s',
#  'MagpieData mean ZungerPP-r_s',
#  'MagpieData avg_dev ZungerPP-r_s',
#  'MagpieData range ZungerPP-r_s']

# %%
# exp查看Nan值超过20%的特征
exp_nan = exp_featurized_df.isna().sum() / len(exp_featurized_df)
exp_nan = exp_nan[exp_nan > 0.1]
exp_nan = exp_nan.index.tolist()
exp_nan
# Out:
# ['MagpieData minimum n_ws^third',
#  'MagpieData maximum n_ws^third',
#  'MagpieData mean n_ws^third',
#  'MagpieData avg_dev n_ws^third',
#  'MagpieData range n_ws^third',
#  'MagpieData mode n_ws^third',
#  'MagpieData minimum phi',
#  'MagpieData maximum phi',
#  'MagpieData mean phi',
#  'MagpieData avg_dev phi',
#  'MagpieData range phi',
#  'MagpieData mode phi',
#  'MagpieData minimum ZungerPP-r_p',
#  'MagpieData maximum ZungerPP-r_p',
#  'MagpieData mean ZungerPP-r_p',
#  'MagpieData avg_dev ZungerPP-r_p',
#  'MagpieData range ZungerPP-r_p',
#  'MagpieData minimum ZungerPP-r_pi',
#  'MagpieData maximum ZungerPP-r_pi',
#  'MagpieData mean ZungerPP-r_pi',
#  'MagpieData avg_dev ZungerPP-r_pi',
#  'MagpieData range ZungerPP-r_pi',
#  'MagpieData minimum ZungerPP-r_s',
#  'MagpieData maximum ZungerPP-r_s',
#  'MagpieData mean ZungerPP-r_s',
#  'MagpieData avg_dev ZungerPP-r_s',
#  'MagpieData range ZungerPP-r_s']

# %%
# n_ws^third/phi/ZungerPP-r_p/ZungerPP-r_pi/ZungerPP-r_s特征Nan值超过0.1，我们也不使用这5个特征
# 重新提取特征
# composition-based features
from matminer.featurizers.composition import ElementProperty
# 某些元素不存在"BulkModulus1"特征，我们不使用该特征
# 总共38个特征，6个统计量， 即38*6=228个特征
features=["Number","AtomicRadius","AtomicVolume","AtomicWeight","MolarVolume","SpaceGroupNumber","CovalentRadius","Density",
          "Column","Electronegativity","ElectronAffinity","FirstIonizationEnergy",
          "DipolePolarizability","Polarizability","BoilingT","MeltingT","ThermalConductivity","LogThermalConductivity",
          "HeatVaporization","HeatFusion","FusionEnthalpy","GSbandgap","GSenergy_pa","GSestBCClatcnt","GSestFCClatcnt","GSvolume_pa",
          "GSmagmom","NUnfilled","NValence","NdUnfilled","NdValence","NfUnfilled","NfValence","NpUnfilled","NpValence","NsUnfilled",
          "NsValence","ZungerPP-r_sigma"]
stats = ["minimum", "maximum", "mean", "avg_dev", "range", "mode"] 

featurizer = ElementProperty(data_source='magpie', features=features, stats=stats) 	# extracting features from a predefined database， e.g. magpie, jarvis, etc.
mp_featurized_df = featurizer.featurize_dataframe(mp_df, col_id='composition')
exp_featurized_df = featurizer.featurize_dataframe(exp_df, col_id='composition')
mp_featurized_df.shape, exp_featurized_df.shape
# Out:
# /home/codespace/.python/current/lib/python3.12/site-packages/matminer/utils/data.py:326: UserWarning: MagpieData(impute_nan=False):
# In a future release, impute_nan will be set to True by default.
#                     This means that features that are missing or are NaNs for elements
#                     from the data source will be replaced by the average of that value
#                     over the available elements.
#                     This avoids NaNs after featurization that are often replaced by
#                     dataset-dependent averages.
#   warnings.warn(f"{self.__class__.__name__}(impute_nan=False):\n" + IMPUTE_NAN_WARNING)
# ElementProperty:   0%|          | 0/10342 [00:00<?, ?it/s]
# ElementProperty:   0%|          | 0/3130 [00:00<?, ?it/s]
# ((10342, 231), (3130, 231))

# %%
# 查看存在Nan值的列
mp_nan = mp_featurized_df.isna().sum() / len(mp_featurized_df)
mp_nan = mp_nan[mp_nan > 0]
# mp_nan = mp_nan.index.tolist()
mp_nan
# Out:
# MagpieData minimum AtomicRadius        0.005898
# MagpieData maximum AtomicRadius        0.005898
# MagpieData mean AtomicRadius           0.005898
# MagpieData avg_dev AtomicRadius        0.005898
# MagpieData range AtomicRadius          0.005898
# MagpieData minimum ElectronAffinity    0.042738
# MagpieData maximum ElectronAffinity    0.042738
# MagpieData mean ElectronAffinity       0.042738
# MagpieData avg_dev ElectronAffinity    0.042738
# MagpieData range ElectronAffinity      0.042738
# MagpieData mode ElectronAffinity       0.001644
# MagpieData minimum HeatFusion          0.000774
# MagpieData maximum HeatFusion          0.000774
# MagpieData mean HeatFusion             0.000774
# MagpieData avg_dev HeatFusion          0.000774
# MagpieData range HeatFusion            0.000774
# MagpieData minimum FusionEnthalpy      0.000774
# MagpieData maximum FusionEnthalpy      0.000774
# MagpieData mean FusionEnthalpy         0.000774
# MagpieData avg_dev FusionEnthalpy      0.000774
# MagpieData range FusionEnthalpy        0.000774
# dtype: float64

# %%
# 查看存在Nan值的行数
mp_na_row = mp_featurized_df.isna().sum(axis=1)
mp_na_row = mp_na_row[mp_na_row > 0]
exp_na_row = exp_featurized_df.isna().sum(axis=1)
exp_na_row = exp_na_row[exp_na_row > 0]
len(mp_na_row), len(exp_na_row)
# Out:
# (510, 21)

# %%
# 对于数值特征，使用均值填充
import numpy as np
numeric_cols_mp = mp_featurized_df.select_dtypes(include=np.number).columns
mp_featurized_df[numeric_cols_mp] = mp_featurized_df[numeric_cols_mp].fillna(mp_featurized_df[numeric_cols_mp].mean())

numeric_cols_exp = exp_featurized_df.select_dtypes(include=np.number).columns
exp_featurized_df[numeric_cols_exp] = exp_featurized_df[numeric_cols_exp].fillna(exp_featurized_df[numeric_cols_exp].mean())

# %%
# 再检查是否存在Nan值
mp_featurized_df.isna().sum().sum(), exp_featurized_df.isna().sum().sum()
# Out:
# (np.int64(0), np.int64(0))

# %%
mp_featurized_df.drop(columns=['composition'], inplace=True)    
mp_featurized_df.rename(columns={'composition_str': 'composition'}, inplace=True)
mp_featurized_df.head()
# Out:
#   composition  band_gap  MagpieData minimum Number  MagpieData maximum Number  \
# 0     Ac16S24    2.2962                       16.0                       89.0
# 1   Ac1Ag1Te2    0.0794                       47.0                       89.0
# 2    Ac1Cr1O3    2.0031                        8.0                       89.0
# 3    Ac1Fe1O3    0.9888                        8.0                       89.0
# 4    Ac1Ga1O3    2.8959                        8.0                       89.0
#
#    MagpieData mean Number  MagpieData avg_dev Number  MagpieData range Number  \
# 0                    45.2                      35.04                     73.0
# 1                    60.0                      14.50                     42.0
# 2                    27.4                      24.64                     81.0
# 3                    27.8                      24.48                     81.0
# 4                    28.8                      24.96                     81.0
#
#    MagpieData mode Number  MagpieData minimum AtomicRadius  \
# 0                    16.0                              1.0
# 1                    52.0                              1.4
# 2                     8.0                              0.6
# 3                     8.0                              0.6
# 4                     8.0                              0.6
#
#    MagpieData maximum AtomicRadius  ...  MagpieData mean NsValence  \
# 0                             1.95  ...                       2.00
# 1                             1.95  ...                       1.75
# 2                             1.95  ...                       1.80
# 3                             1.95  ...                       2.00
# 4                             1.95  ...                       2.00
#
#    MagpieData avg_dev NsValence  MagpieData range NsValence  \
# 0                         0.000                         0.0
# 1                         0.375                         1.0
# 2                         0.320                         1.0
# 3                         0.000                         0.0
# 4                         0.000                         0.0
#
#    MagpieData mode NsValence  MagpieData minimum ZungerPP-r_sigma  \
# 0                        2.0                                1.100
# 1                        2.0                                1.670
# 2                        2.0                                0.465
# 3                        2.0                                0.465
# 4                        2.0                                0.465
#
#    MagpieData maximum ZungerPP-r_sigma  MagpieData mean ZungerPP-r_sigma  \
# 0                                 3.12                           1.90800
# 1                                 3.12                           2.20875
# 2                                 3.12                           1.39100
# 3                                 3.12                           1.32500
# 4                                 3.12                           1.24200
#
#    MagpieData avg_dev ZungerPP-r_sigma  MagpieData range ZungerPP-r_sigma  \
# 0                              0.96960                              2.020
# 1                              0.53875                              1.450
# 2                              1.11120                              2.655
# 3                              1.03200                              2.655
# 4                              0.93240                              2.655
#
#    MagpieData mode ZungerPP-r_sigma
# 0                             1.100
# 1                             1.670
# 2                             0.465
# 3                             0.465
# 4                             0.465
#
# [5 rows x 230 columns]

# %%
exp_featurized_df.drop(columns=['composition'], inplace=True)
exp_featurized_df.rename(columns={'composition_str': 'composition'}, inplace=True)
exp_featurized_df.head()
# Out:
#      composition  band_gap  MagpieData minimum Number  \
# 0  Hg0.7Cd0.3Te1      0.35                       48.0
# 1          Lu1P1      1.30                       15.0
# 2      Cu3Sb1Se4      0.40                       29.0
# 3         Pt1Sb2      0.08                       51.0
# 4       Zn1In2S4      2.68                       16.0
#
#    MagpieData maximum Number  MagpieData mean Number  \
# 0                       80.0               61.200000
# 1                       71.0               43.000000
# 2                       51.0               34.250000
# 3                       78.0               60.000000
# 4                       49.0               27.428571
#
#    MagpieData avg_dev Number  MagpieData range Number  MagpieData mode Number  \
# 0                  13.160000                     32.0                    52.0
# 1                  28.000000                     56.0                    15.0
# 2                   4.187500                     22.0                    34.0
# 3                  12.000000                     27.0                    51.0
# 4                  13.061224                     33.0                    16.0
#
#    MagpieData minimum AtomicRadius  MagpieData maximum AtomicRadius  ...  \
# 0                             1.40                             1.55  ...
# 1                             1.00                             1.75  ...
# 2                             1.15                             1.45  ...
# 3                             1.35                             1.45  ...
# 4                             1.00                             1.55  ...
#
#    MagpieData mean NsValence  MagpieData avg_dev NsValence  \
# 0                   2.000000                      0.000000
# 1                   2.000000                      0.000000
# 2                   1.625000                      0.468750
# 3                   1.666667                      0.444444
# 4                   2.000000                      0.000000
#
#    MagpieData range NsValence  MagpieData mode NsValence  \
# 0                         0.0                        2.0
# 1                         0.0                        2.0
# 2                         1.0                        2.0
# 3                         1.0                        2.0
# 4                         0.0                        2.0
#
#    MagpieData minimum ZungerPP-r_sigma  MagpieData maximum ZungerPP-r_sigma  \
# 0                                1.670                                 2.41
# 1                                1.240                                 3.37
# 2                                1.285                                 2.04
# 3                                1.765                                 2.70
# 4                                1.100                                 2.05
#
#    MagpieData mean ZungerPP-r_sigma  MagpieData avg_dev ZungerPP-r_sigma  \
# 0                          2.010750                             0.340750
# 1                          2.305000                             1.065000
# 2                          1.628125                             0.343125
# 3                          2.076667                             0.415556
# 4                          1.482857                             0.437551
#
#    MagpieData range ZungerPP-r_sigma  MagpieData mode ZungerPP-r_sigma
# 0                              0.740                             1.670
# 1                              2.130                             1.240
# 2                              0.755                             1.285
# 3                              0.935                             1.765
# 4                              0.950                             1.100
#
# [5 rows x 230 columns]

# %%
# 将列名去掉MagpieData
mp_featurized_df.columns = mp_featurized_df.columns.str.replace('MagpieData ', '')
exp_featurized_df.columns = exp_featurized_df.columns.str.replace('MagpieData ', '')
mp_featurized_df.head()
# Out:
#   composition  band_gap  minimum Number  maximum Number  mean Number  \
# 0     Ac16S24    2.2962            16.0            89.0         45.2
# 1   Ac1Ag1Te2    0.0794            47.0            89.0         60.0
# 2    Ac1Cr1O3    2.0031             8.0            89.0         27.4
# 3    Ac1Fe1O3    0.9888             8.0            89.0         27.8
# 4    Ac1Ga1O3    2.8959             8.0            89.0         28.8
#
#    avg_dev Number  range Number  mode Number  minimum AtomicRadius  \
# 0           35.04          73.0         16.0                   1.0
# 1           14.50          42.0         52.0                   1.4
# 2           24.64          81.0          8.0                   0.6
# 3           24.48          81.0          8.0                   0.6
# 4           24.96          81.0          8.0                   0.6
#
#    maximum AtomicRadius  ...  mean NsValence  avg_dev NsValence  \
# 0                  1.95  ...            2.00              0.000
# 1                  1.95  ...            1.75              0.375
# 2                  1.95  ...            1.80              0.320
# 3                  1.95  ...            2.00              0.000
# 4                  1.95  ...            2.00              0.000
#
#    range NsValence  mode NsValence  minimum ZungerPP-r_sigma  \
# 0              0.0             2.0                     1.100
# 1              1.0             2.0                     1.670
# 2              1.0             2.0                     0.465
# 3              0.0             2.0                     0.465
# 4              0.0             2.0                     0.465
#
#    maximum ZungerPP-r_sigma  mean ZungerPP-r_sigma  avg_dev ZungerPP-r_sigma  \
# 0                      3.12                1.90800                   0.96960
# 1                      3.12                2.20875                   0.53875
# 2                      3.12                1.39100                   1.11120
# 3                      3.12                1.32500                   1.03200
# 4                      3.12                1.24200                   0.93240
#
#    range ZungerPP-r_sigma  mode ZungerPP-r_sigma
# 0                   2.020                  1.100
# 1                   1.450                  1.670
# 2                   2.655                  0.465
# 3                   2.655                  0.465
# 4                   2.655                  0.465
#
# [5 rows x 230 columns]

# %%
exp_featurized_df.head()
# Out:
#      composition  band_gap  minimum Number  maximum Number  mean Number  \
# 0  Hg0.7Cd0.3Te1      0.35            48.0            80.0    61.200000
# 1          Lu1P1      1.30            15.0            71.0    43.000000
# 2      Cu3Sb1Se4      0.40            29.0            51.0    34.250000
# 3         Pt1Sb2      0.08            51.0            78.0    60.000000
# 4       Zn1In2S4      2.68            16.0            49.0    27.428571
#
#    avg_dev Number  range Number  mode Number  minimum AtomicRadius  \
# 0       13.160000          32.0         52.0                  1.40
# 1       28.000000          56.0         15.0                  1.00
# 2        4.187500          22.0         34.0                  1.15
# 3       12.000000          27.0         51.0                  1.35
# 4       13.061224          33.0         16.0                  1.00
#
#    maximum AtomicRadius  ...  mean NsValence  avg_dev NsValence  \
# 0                  1.55  ...        2.000000           0.000000
# 1                  1.75  ...        2.000000           0.000000
# 2                  1.45  ...        1.625000           0.468750
# 3                  1.45  ...        1.666667           0.444444
# 4                  1.55  ...        2.000000           0.000000
#
#    range NsValence  mode NsValence  minimum ZungerPP-r_sigma  \
# 0              0.0             2.0                     1.670
# 1              0.0             2.0                     1.240
# 2              1.0             2.0                     1.285
# 3              1.0             2.0                     1.765
# 4              0.0             2.0                     1.100
#
#    maximum ZungerPP-r_sigma  mean ZungerPP-r_sigma  avg_dev ZungerPP-r_sigma  \
# 0                      2.41               2.010750                  0.340750
# 1                      3.37               2.305000                  1.065000
# 2                      2.04               1.628125                  0.343125
# 3                      2.70               2.076667                  0.415556
# 4                      2.05               1.482857                  0.437551
#
#    range ZungerPP-r_sigma  mode ZungerPP-r_sigma
# 0                   0.740                  1.670
# 1                   2.130                  1.240
# 2                   0.755                  1.285
# 3                   0.935                  1.765
# 4                   0.950                  1.100
#
# [5 rows x 230 columns]

# %% [markdown]
# ### 2. MP数据加入其他物理特征

# %%
# load the data
mp_plus_df = pd.read_csv('./Data/plus_data/mp_band_gap_plus.csv')

# %%
mp_plus_df.head()
# Out:
#   material_id composition  nsites  crystal_system  space_group       volume  \
# 0    mp-32800     Ac16S24      40               1          122  1118.407852
# 1   mp-867311   Ac1Ag1Te2       4               0          225   122.518406
# 2   mp-866101    Ac1Cr1O3       5               0          221    61.362845
# 3   mp-861502    Ac1Fe1O3       5               0          221    61.797311
# 4  mp-1183053    Ac1Ga1O3       5               0          221    61.455078
#
#     density  density_atomic    efermi  energy_per_atom  \
# 0  6.535149       27.960196  5.791820       -34.768478
# 1  7.997421       30.629602  6.031096       -36.203183
# 2  8.848788       12.272569  6.364737        -8.862593
# 3  8.889999       12.359462  6.509045        -8.258555
# 4  9.314495       12.291016  5.476935        -7.461883
#
#    formation_energy_per_atom  is_gap_direct  band_gap  is_oxide
# 0                  -2.492486            0.0    2.2962       0.0
# 1                  -0.996232            0.0    0.0794       0.0
# 2                  -3.138972            0.0    2.0031       1.0
# 3                  -2.771539            0.0    0.9888       1.0
# 4                  -3.063253            0.0    2.8959       1.0

# %%
mp_plus_df.rename(columns={'composition': 'composition_str'}, inplace=True)

# %%
from matminer.featurizers.conversions import StrToComposition

stc = StrToComposition(target_col_id='composition')
mp_plus_df = stc.featurize_dataframe(mp_plus_df, col_id="composition_str", pbar=True)
# Out:
# StrToComposition:   0%|          | 0/10342 [00:00<?, ?it/s]

# %%
# composition-based features
mp_featurized_df2 = featurizer.featurize_dataframe(mp_plus_df, col_id='composition')
# Out:
# ElementProperty:   0%|          | 0/10342 [00:00<?, ?it/s]

# %%
mp_featurized_df2.head()
# Out:
#   material_id composition_str  nsites  crystal_system  space_group  \
# 0    mp-32800         Ac16S24      40               1          122
# 1   mp-867311       Ac1Ag1Te2       4               0          225
# 2   mp-866101        Ac1Cr1O3       5               0          221
# 3   mp-861502        Ac1Fe1O3       5               0          221
# 4  mp-1183053        Ac1Ga1O3       5               0          221
#
#         volume   density  density_atomic    efermi  energy_per_atom  ...  \
# 0  1118.407852  6.535149       27.960196  5.791820       -34.768478  ...
# 1   122.518406  7.997421       30.629602  6.031096       -36.203183  ...
# 2    61.362845  8.848788       12.272569  6.364737        -8.862593  ...
# 3    61.797311  8.889999       12.359462  6.509045        -8.258555  ...
# 4    61.455078  9.314495       12.291016  5.476935        -7.461883  ...
#
#    MagpieData mean NsValence  MagpieData avg_dev NsValence  \
# 0                       2.00                         0.000
# 1                       1.75                         0.375
# 2                       1.80                         0.320
# 3                       2.00                         0.000
# 4                       2.00                         0.000
#
#    MagpieData range NsValence  MagpieData mode NsValence  \
# 0                         0.0                        2.0
# 1                         1.0                        2.0
# 2                         1.0                        2.0
# 3                         0.0                        2.0
# 4                         0.0                        2.0
#
#   MagpieData minimum ZungerPP-r_sigma  MagpieData maximum ZungerPP-r_sigma  \
# 0                               1.100                                 3.12
# 1                               1.670                                 3.12
# 2                               0.465                                 3.12
# 3                               0.465                                 3.12
# 4                               0.465                                 3.12
#
#    MagpieData mean ZungerPP-r_sigma  MagpieData avg_dev ZungerPP-r_sigma  \
# 0                           1.90800                              0.96960
# 1                           2.20875                              0.53875
# 2                           1.39100                              1.11120
# 3                           1.32500                              1.03200
# 4                           1.24200                              0.93240
#
#    MagpieData range ZungerPP-r_sigma  MagpieData mode ZungerPP-r_sigma
# 0                              2.020                             1.100
# 1                              1.450                             1.670
# 2                              2.655                             0.465
# 3                              2.655                             0.465
# 4                              2.655                             0.465
#
# [5 rows x 243 columns]

# %%
# 查看存在Nan值的行数
mp_na_row = mp_featurized_df2.isna().sum(axis=1)
mp_na_row = mp_na_row[mp_na_row > 0]
len(mp_na_row)
# Out:
# 510

# %%
# 对于数值特征，使用均值填充
numeric_cols_mp = mp_featurized_df2.select_dtypes(include=np.number).columns
mp_featurized_df2[numeric_cols_mp] = mp_featurized_df2[numeric_cols_mp].fillna(mp_featurized_df2[numeric_cols_mp].mean())
# 再检查是否存在Nan值
mp_featurized_df2.isna().sum().sum()
# Out:
# np.int64(0)

# %%
mp_featurized_df2['composition_str'] = mp_featurized_df2['composition']
mp_featurized_df2.drop(columns=['composition'], inplace=True)    
mp_featurized_df2.rename(columns={'composition_str': 'composition'}, inplace=True)
mp_featurized_df2['composition'] = mp_featurized_df2['composition'].apply(lambda x: str(x).replace(" ", ""))
mp_featurized_df2.head()
# Out:
#   material_id composition  nsites  crystal_system  space_group       volume  \
# 0    mp-32800     Ac16S24      40               1          122  1118.407852
# 1   mp-867311   Ac1Ag1Te2       4               0          225   122.518406
# 2   mp-866101    Ac1Cr1O3       5               0          221    61.362845
# 3   mp-861502    Ac1Fe1O3       5               0          221    61.797311
# 4  mp-1183053    Ac1Ga1O3       5               0          221    61.455078
#
#     density  density_atomic    efermi  energy_per_atom  ...  \
# 0  6.535149       27.960196  5.791820       -34.768478  ...
# 1  7.997421       30.629602  6.031096       -36.203183  ...
# 2  8.848788       12.272569  6.364737        -8.862593  ...
# 3  8.889999       12.359462  6.509045        -8.258555  ...
# 4  9.314495       12.291016  5.476935        -7.461883  ...
#
#    MagpieData mean NsValence  MagpieData avg_dev NsValence  \
# 0                       2.00                         0.000
# 1                       1.75                         0.375
# 2                       1.80                         0.320
# 3                       2.00                         0.000
# 4                       2.00                         0.000
#
#    MagpieData range NsValence  MagpieData mode NsValence  \
# 0                         0.0                        2.0
# 1                         1.0                        2.0
# 2                         1.0                        2.0
# 3                         0.0                        2.0
# 4                         0.0                        2.0
#
#    MagpieData minimum ZungerPP-r_sigma  MagpieData maximum ZungerPP-r_sigma  \
# 0                                1.100                                 3.12
# 1                                1.670                                 3.12
# 2                                0.465                                 3.12
# 3                                0.465                                 3.12
# 4                                0.465                                 3.12
#
#    MagpieData mean ZungerPP-r_sigma  MagpieData avg_dev ZungerPP-r_sigma  \
# 0                           1.90800                              0.96960
# 1                           2.20875                              0.53875
# 2                           1.39100                              1.11120
# 3                           1.32500                              1.03200
# 4                           1.24200                              0.93240
#
#    MagpieData range ZungerPP-r_sigma  MagpieData mode ZungerPP-r_sigma
# 0                              2.020                             1.100
# 1                              1.450                             1.670
# 2                              2.655                             0.465
# 3                              2.655                             0.465
# 4                              2.655                             0.465
#
# [5 rows x 242 columns]

# %%
mp_featurized_df2.drop(columns=['material_id'], inplace=True)

# %%
mp_featurized_df2.columns = mp_featurized_df2.columns.str.replace('MagpieData ', '')
mp_featurized_df2.head()
# Out:
#   composition  nsites  crystal_system  space_group       volume   density  \
# 0     Ac16S24      40               1          122  1118.407852  6.535149
# 1   Ac1Ag1Te2       4               0          225   122.518406  7.997421
# 2    Ac1Cr1O3       5               0          221    61.362845  8.848788
# 3    Ac1Fe1O3       5               0          221    61.797311  8.889999
# 4    Ac1Ga1O3       5               0          221    61.455078  9.314495
#
#    density_atomic    efermi  energy_per_atom  formation_energy_per_atom  ...  \
# 0       27.960196  5.791820       -34.768478                  -2.492486  ...
# 1       30.629602  6.031096       -36.203183                  -0.996232  ...
# 2       12.272569  6.364737        -8.862593                  -3.138972  ...
# 3       12.359462  6.509045        -8.258555                  -2.771539  ...
# 4       12.291016  5.476935        -7.461883                  -3.063253  ...
#
#    mean NsValence  avg_dev NsValence  range NsValence  mode NsValence  \
# 0            2.00              0.000              0.0             2.0
# 1            1.75              0.375              1.0             2.0
# 2            1.80              0.320              1.0             2.0
# 3            2.00              0.000              0.0             2.0
# 4            2.00              0.000              0.0             2.0
#
#    minimum ZungerPP-r_sigma  maximum ZungerPP-r_sigma  mean ZungerPP-r_sigma  \
# 0                     1.100                      3.12                1.90800
# 1                     1.670                      3.12                2.20875
# 2                     0.465                      3.12                1.39100
# 3                     0.465                      3.12                1.32500
# 4                     0.465                      3.12                1.24200
#
#    avg_dev ZungerPP-r_sigma  range ZungerPP-r_sigma  mode ZungerPP-r_sigma
# 0                   0.96960                   2.020                  1.100
# 1                   0.53875                   1.450                  1.670
# 2                   1.11120                   2.655                  0.465
# 3                   1.03200                   2.655                  0.465
# 4                   0.93240                   2.655                  0.465
#
# [5 rows x 241 columns]

# %% [markdown]
# ## Save Data

# %%
# save the data to csv file
import os
file_path = os.path.join(os.getcwd(), "./Data/featured_data")
os.makedirs(file_path, exist_ok=True)
mp_featurized_df.to_csv(os.path.join(file_path, 'mp_elements_feat.csv'), index=False)
exp_featurized_df.to_csv(os.path.join(file_path, 'exp_elements_feat.csv'), index=False)
mp_featurized_df2.to_csv(os.path.join(file_path, 'mp_elements_plus_feat.csv'), index=False)
