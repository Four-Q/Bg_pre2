# %% [markdown]
# # Recursive Feature Elimination(RFE)
#
# **递归特征消除**：
# 反复构建模型，每次迭代移除最不重要的特征，直到达到所需的特征数量。

# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set random seed for reproducibility
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
current_path = os.getcwd()

# To import the custom module from a specific path
sys.path.insert(0, os.path.join(current_path))

# %%
# Load data (assuming you have dft_train_X, dft_train_y)
file_dir = os.path.join(current_path, './Data')
# Load dft data
dft_train = pd.read_csv(os.path.join(file_dir, 'train_data', 'mp_train_set.csv'))
dft_all_train_X = dft_train.drop(columns=['composition', 'band_gap'])
dft_all_train_y = dft_train['band_gap']
dft_all_train_X.shape, dft_all_train_y.shape
# Out:
# ((8275, 228), (8275,))

# %%
# 从dft_train_X中抽取出一份验证集
mp_unique_comp = dft_train['composition'].unique()
len(mp_unique_comp)
# Out:
# 8244

# %%
import random
# 从mp_unique_comp中随机采样组成
random.seed(RANDOM_SEED)
random_index = random.sample(range(len(mp_unique_comp)), round(dft_train.shape[0]*0.2))
mp_val_comp = mp_unique_comp[random_index]
dft_train_set = dft_train[~dft_train['composition'].isin(mp_val_comp)]
dft_val_set = dft_train[dft_train['composition'].isin(mp_val_comp)]
print(f'MP训练集大小：{len(dft_train_set)}')
print(f'MP验证集大小：{len(dft_val_set)}')
# Out:
# MP训练集大小：6614
# MP验证集大小：1661

# %%
# Prepare data
dft_train_X = dft_train_set.drop(columns=['composition', 'band_gap'])
dft_train_y = dft_train_set['band_gap']
# 
dft_val_X = dft_val_set.drop(columns=['composition', 'band_gap'])
dft_val_y = dft_val_set['band_gap']

dft_train_X.shape, dft_train_y.shape, dft_val_X.shape, dft_val_y.shape
# Out:
# ((6614, 228), (6614,), (1661, 228), (1661,))

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import RFE
from sklearn.metrics import mean_squared_error

# %%
# 为加快运行速度，自己实现RFE
def custom_rfe(model, X, y, X_val, y_val, target_features, step=1, verbose=True):
    """
    自定义递归特征消除函数
    """
    # 存储每一步rmse
    rmse_scores = []
    # 存储每一步选中的特征
    selected_features = []
    while X.shape[1] >= target_features:
        # 训练模型
        model.fit(X, y)
        
        # 获取特征重要性
        importances = model.feature_importances_
        
        # 获取特征索引
        feature_indices = np.argsort(importances)[::-1]
        # 
        selected_features.append(X.columns[feature_indices])
        
        # 在验证集上进行预测
        y_pred = model.predict(X_val)
        # 计算均方根误差 (RMSE)
        rmse = np.sqrt(mean_squared_error(y_val, y_pred))
        rmse_scores.append(rmse)
        # 打印进度
        if verbose:
            print(f"Feature nums: {X.shape[1]}, RMSE: {rmse:.4f}")

        # 删除最不重要的特征
        X = X.iloc[:, feature_indices[:-step]]
        X_val = X_val.iloc[:, feature_indices[:-step]]

    return selected_features, rmse_scores

# 使用自定义的 RFE 函数
model = RandomForestRegressor(
    n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=1,
    max_features=0.5, random_state=RANDOM_SEED, n_jobs=-1)
# 特征缩放
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dft_train_X = pd.DataFrame(scaler.fit_transform(dft_train_X), columns=dft_train_X.columns)
dft_val_X = pd.DataFrame(scaler.transform(dft_val_X), columns=dft_val_X.columns)
selected_features, rmse_scores = custom_rfe(model, dft_train_X, dft_train_y, dft_val_X, dft_val_y, target_features=1, step=1, verbose=True)
# Out:
# Feature nums: 228, RMSE: 0.5435
# Feature nums: 227, RMSE: 0.5405
# Feature nums: 226, RMSE: 0.5440
# Feature nums: 225, RMSE: 0.5430
# Feature nums: 224, RMSE: 0.5428
# Feature nums: 223, RMSE: 0.5419
# Feature nums: 222, RMSE: 0.5437
# Feature nums: 221, RMSE: 0.5426
# Feature nums: 220, RMSE: 0.5403
# Feature nums: 219, RMSE: 0.5442
# Feature nums: 218, RMSE: 0.5398
# Feature nums: 217, RMSE: 0.5428
# Feature nums: 216, RMSE: 0.5410
# Feature nums: 215, RMSE: 0.5433
# Feature nums: 214, RMSE: 0.5433
# Feature nums: 213, RMSE: 0.5436
# Feature nums: 212, RMSE: 0.5387
# Feature nums: 211, RMSE: 0.5429
# Feature nums: 210, RMSE: 0.5428
# Feature nums: 209, RMSE: 0.5403
# Feature nums: 208, RMSE: 0.5425
# Feature nums: 207, RMSE: 0.5418
# Feature nums: 206, RMSE: 0.5443
# Feature nums: 205, RMSE: 0.5403
# Feature nums: 204, RMSE: 0.5414
# Feature nums: 203, RMSE: 0.5417
# Feature nums: 202, RMSE: 0.5453
# Feature nums: 201, RMSE: 0.5438
# Feature nums: 200, RMSE: 0.5443
# Feature nums: 199, RMSE: 0.5434
# Feature nums: 198, RMSE: 0.5407
# Feature nums: 197, RMSE: 0.5411
# Feature nums: 196, RMSE: 0.5427
# Feature nums: 195, RMSE: 0.5467
# Feature nums: 194, RMSE: 0.5422
# Feature nums: 193, RMSE: 0.5456
# Feature nums: 192, RMSE: 0.5429
# Feature nums: 191, RMSE: 0.5430
# Feature nums: 190, RMSE: 0.5420
# Feature nums: 189, RMSE: 0.5452
# Feature nums: 188, RMSE: 0.5404
# Feature nums: 187, RMSE: 0.5414
# Feature nums: 186, RMSE: 0.5420
# Feature nums: 185, RMSE: 0.5410
# Feature nums: 184, RMSE: 0.5400
# Feature nums: 183, RMSE: 0.5414
# Feature nums: 182, RMSE: 0.5448
# Feature nums: 181, RMSE: 0.5418
# Feature nums: 180, RMSE: 0.5434
# Feature nums: 179, RMSE: 0.5398
# Feature nums: 178, RMSE: 0.5450
# Feature nums: 177, RMSE: 0.5450
# Feature nums: 176, RMSE: 0.5444
# Feature nums: 175, RMSE: 0.5398
# Feature nums: 174, RMSE: 0.5414
# Feature nums: 173, RMSE: 0.5393
# Feature nums: 172, RMSE: 0.5408
# Feature nums: 171, RMSE: 0.5449
# Feature nums: 170, RMSE: 0.5448
# Feature nums: 169, RMSE: 0.5409
# Feature nums: 168, RMSE: 0.5427
# Feature nums: 167, RMSE: 0.5444
# Feature nums: 166, RMSE: 0.5422
# Feature nums: 165, RMSE: 0.5427
# Feature nums: 164, RMSE: 0.5453
# Feature nums: 163, RMSE: 0.5427
# Feature nums: 162, RMSE: 0.5466
# Feature nums: 161, RMSE: 0.5446
# Feature nums: 160, RMSE: 0.5425
# Feature nums: 159, RMSE: 0.5426
# Feature nums: 158, RMSE: 0.5450
# Feature nums: 157, RMSE: 0.5413
# Feature nums: 156, RMSE: 0.5430
# Feature nums: 155, RMSE: 0.5429
# Feature nums: 154, RMSE: 0.5422
# Feature nums: 153, RMSE: 0.5422
# Feature nums: 152, RMSE: 0.5453
# Feature nums: 151, RMSE: 0.5430
# Feature nums: 150, RMSE: 0.5417
# Feature nums: 149, RMSE: 0.5422
# Feature nums: 148, RMSE: 0.5462
# Feature nums: 147, RMSE: 0.5461
# Feature nums: 146, RMSE: 0.5407
# Feature nums: 145, RMSE: 0.5407
# Feature nums: 144, RMSE: 0.5446
# Feature nums: 143, RMSE: 0.5457
# Feature nums: 142, RMSE: 0.5434
# Feature nums: 141, RMSE: 0.5438
# Feature nums: 140, RMSE: 0.5437
# Feature nums: 139, RMSE: 0.5456
# Feature nums: 138, RMSE: 0.5424
# Feature nums: 137, RMSE: 0.5469
# Feature nums: 136, RMSE: 0.5436
# Feature nums: 135, RMSE: 0.5444
# Feature nums: 134, RMSE: 0.5455
# Feature nums: 133, RMSE: 0.5424
# Feature nums: 132, RMSE: 0.5441
# Feature nums: 131, RMSE: 0.5422
# Feature nums: 130, RMSE: 0.5461
# Feature nums: 129, RMSE: 0.5453
# Feature nums: 128, RMSE: 0.5444
# Feature nums: 127, RMSE: 0.5423
# Feature nums: 126, RMSE: 0.5460
# Feature nums: 125, RMSE: 0.5448
# Feature nums: 124, RMSE: 0.5452
# Feature nums: 123, RMSE: 0.5434
# Feature nums: 122, RMSE: 0.5455
# Feature nums: 121, RMSE: 0.5456
# Feature nums: 120, RMSE: 0.5427
# Feature nums: 119, RMSE: 0.5454
# Feature nums: 118, RMSE: 0.5437
# Feature nums: 117, RMSE: 0.5411
# Feature nums: 116, RMSE: 0.5470
# Feature nums: 115, RMSE: 0.5438
# Feature nums: 114, RMSE: 0.5443
# Feature nums: 113, RMSE: 0.5441
# Feature nums: 112, RMSE: 0.5419
# Feature nums: 111, RMSE: 0.5447
# Feature nums: 110, RMSE: 0.5451
# Feature nums: 109, RMSE: 0.5440
# Feature nums: 108, RMSE: 0.5449
# Feature nums: 107, RMSE: 0.5449
# Feature nums: 106, RMSE: 0.5457
# Feature nums: 105, RMSE: 0.5432
# Feature nums: 104, RMSE: 0.5430
# Feature nums: 103, RMSE: 0.5442
# Feature nums: 102, RMSE: 0.5454
# Feature nums: 101, RMSE: 0.5452
# Feature nums: 100, RMSE: 0.5435
# Feature nums: 99, RMSE: 0.5415
# Feature nums: 98, RMSE: 0.5420
# Feature nums: 97, RMSE: 0.5425
# Feature nums: 96, RMSE: 0.5440
# Feature nums: 95, RMSE: 0.5440
# Feature nums: 94, RMSE: 0.5427
# Feature nums: 93, RMSE: 0.5416
# Feature nums: 92, RMSE: 0.5421
# Feature nums: 91, RMSE: 0.5425
# Feature nums: 90, RMSE: 0.5424
# Feature nums: 89, RMSE: 0.5423
# Feature nums: 88, RMSE: 0.5418
# Feature nums: 87, RMSE: 0.5419
# Feature nums: 86, RMSE: 0.5424
# Feature nums: 85, RMSE: 0.5455
# Feature nums: 84, RMSE: 0.5420
# Feature nums: 83, RMSE: 0.5422
# Feature nums: 82, RMSE: 0.5438
# Feature nums: 81, RMSE: 0.5403
# Feature nums: 80, RMSE: 0.5430
# Feature nums: 79, RMSE: 0.5396
# Feature nums: 78, RMSE: 0.5413
# Feature nums: 77, RMSE: 0.5410
# Feature nums: 76, RMSE: 0.5450
# Feature nums: 75, RMSE: 0.5422
# Feature nums: 74, RMSE: 0.5433
# Feature nums: 73, RMSE: 0.5395
# Feature nums: 72, RMSE: 0.5386
# Feature nums: 71, RMSE: 0.5394
# Feature nums: 70, RMSE: 0.5426
# Feature nums: 69, RMSE: 0.5400
# Feature nums: 68, RMSE: 0.5407
# Feature nums: 67, RMSE: 0.5415
# Feature nums: 66, RMSE: 0.5456
# Feature nums: 65, RMSE: 0.5437
# Feature nums: 64, RMSE: 0.5383
# Feature nums: 63, RMSE: 0.5412
# Feature nums: 62, RMSE: 0.5452
# Feature nums: 61, RMSE: 0.5432
# Feature nums: 60, RMSE: 0.5449
# Feature nums: 59, RMSE: 0.5416
# Feature nums: 58, RMSE: 0.5419
# Feature nums: 57, RMSE: 0.5391
# Feature nums: 56, RMSE: 0.5420
# Feature nums: 55, RMSE: 0.5429
# Feature nums: 54, RMSE: 0.5443
# Feature nums: 53, RMSE: 0.5445
# Feature nums: 52, RMSE: 0.5457
# Feature nums: 51, RMSE: 0.5455
# Feature nums: 50, RMSE: 0.5408
# Feature nums: 49, RMSE: 0.5405
# Feature nums: 48, RMSE: 0.5446
# Feature nums: 47, RMSE: 0.5433
# Feature nums: 46, RMSE: 0.5470
# Feature nums: 45, RMSE: 0.5437
# Feature nums: 44, RMSE: 0.5452
# Feature nums: 43, RMSE: 0.5461
# Feature nums: 42, RMSE: 0.5457
# Feature nums: 41, RMSE: 0.5442
# Feature nums: 40, RMSE: 0.5496
# Feature nums: 39, RMSE: 0.5446
# Feature nums: 38, RMSE: 0.5489
# Feature nums: 37, RMSE: 0.5508
# Feature nums: 36, RMSE: 0.5515
# Feature nums: 35, RMSE: 0.5510
# Feature nums: 34, RMSE: 0.5486
# Feature nums: 33, RMSE: 0.5496
# Feature nums: 32, RMSE: 0.5489
# Feature nums: 31, RMSE: 0.5468
# Feature nums: 30, RMSE: 0.5470
# Feature nums: 29, RMSE: 0.5485
# Feature nums: 28, RMSE: 0.5494
# Feature nums: 27, RMSE: 0.5477
# Feature nums: 26, RMSE: 0.5473
# Feature nums: 25, RMSE: 0.5517
# Feature nums: 24, RMSE: 0.5512
# Feature nums: 23, RMSE: 0.5548
# Feature nums: 22, RMSE: 0.5562
# Feature nums: 21, RMSE: 0.5593
# Feature nums: 20, RMSE: 0.5580
# Feature nums: 19, RMSE: 0.5528
# Feature nums: 18, RMSE: 0.5611
# Feature nums: 17, RMSE: 0.5620
# Feature nums: 16, RMSE: 0.5705
# Feature nums: 15, RMSE: 0.5671
# Feature nums: 14, RMSE: 0.5722
# Feature nums: 13, RMSE: 0.5703
# Feature nums: 12, RMSE: 0.5725
# Feature nums: 11, RMSE: 0.5790
# Feature nums: 10, RMSE: 0.5818
# Feature nums: 9, RMSE: 0.5768
# Feature nums: 8, RMSE: 0.5837
# Feature nums: 7, RMSE: 0.5911
# Feature nums: 6, RMSE: 0.6512
# Feature nums: 5, RMSE: 0.6549
# Feature nums: 4, RMSE: 0.6814
# Feature nums: 3, RMSE: 0.7404
# Feature nums: 2, RMSE: 0.8246
# Feature nums: 1, RMSE: 0.9503

# %%
rmse_scores = rmse_scores[::-1]
selected_features = selected_features[::-1]
rmse_scores
# Out:
# [np.float64(0.9502717609056177),
#  np.float64(0.8246024161609865),
#  np.float64(0.7404366250312542),
#  np.float64(0.6813785375191703),
#  np.float64(0.6549291394110609),
#  np.float64(0.6511552462776775),
#  np.float64(0.5910656428894102),
#  np.float64(0.5836937128073302),
#  np.float64(0.5767605402193878),
#  np.float64(0.5818017640739886),
#  np.float64(0.5789520180226966),
#  np.float64(0.5725392547609649),
#  np.float64(0.5703033192071456),
#  np.float64(0.5722298647758721),
#  np.float64(0.5671280094541173),
#  np.float64(0.5704991770794108),
#  np.float64(0.5620004658085768),
#  np.float64(0.5610739523144217),
#  np.float64(0.5527922547016232),
#  np.float64(0.5579661676176094),
#  np.float64(0.5592765417143588),
#  np.float64(0.5562489638561193),
#  np.float64(0.5547897662679736),
#  np.float64(0.5511728859346986),
#  np.float64(0.5516901257518243),
#  np.float64(0.5473355929268487),
#  np.float64(0.5477281994638199),
#  np.float64(0.5494413188559645),
#  np.float64(0.5485066223804791),
#  np.float64(0.5469651827475382),
#  np.float64(0.5468442702981472),
#  np.float64(0.5488993708846267),
#  np.float64(0.5496118684248218),
#  np.float64(0.5486413415228383),
#  np.float64(0.5509581843523707),
#  np.float64(0.5515077917935142),
#  np.float64(0.5508311551949281),
#  np.float64(0.5488714570877766),
#  np.float64(0.5446033834286851),
#  np.float64(0.5496377175073704),
#  np.float64(0.5441660972369243),
#  np.float64(0.5456637809255693),
#  np.float64(0.5460947756469834),
#  np.float64(0.5452212523768413),
#  np.float64(0.5436709772370023),
#  np.float64(0.5469636933532652),
#  np.float64(0.543318259833846),
#  np.float64(0.5445597295784969),
#  np.float64(0.5404806437168101),
#  np.float64(0.5408485284552538),
#  np.float64(0.545467901864126),
#  np.float64(0.545689816706287),
#  np.float64(0.5445130737386427),
#  np.float64(0.5443002251058702),
#  np.float64(0.5428779600014743),
#  np.float64(0.5420269334121781),
#  np.float64(0.539144316928484),
#  np.float64(0.5419249842194164),
#  np.float64(0.5415643616999873),
#  np.float64(0.5449407425326647),
#  np.float64(0.5431879487835755),
#  np.float64(0.545181431589292),
#  np.float64(0.5412331251325322),
#  np.float64(0.5382898197839586),
#  np.float64(0.5436759224778809),
#  np.float64(0.5456117622376966),
#  np.float64(0.5415197347525537),
#  np.float64(0.5407094390532694),
#  np.float64(0.5400369521691559),
#  np.float64(0.5425681618589423),
#  np.float64(0.5394376344160066),
#  np.float64(0.5386466480870123),
#  np.float64(0.5394825715916008),
#  np.float64(0.5433456655479508),
#  np.float64(0.5421540025124502),
#  np.float64(0.5450393664909438),
#  np.float64(0.540956713862186),
#  np.float64(0.5413299969733797),
#  np.float64(0.539627118550819),
#  np.float64(0.5430457471572665),
#  np.float64(0.5402971206158492),
#  np.float64(0.5437915726170157),
#  np.float64(0.542156705060389),
#  np.float64(0.5419717742021192),
#  np.float64(0.5454982617644991),
#  np.float64(0.5423517431828064),
#  np.float64(0.5419225438758221),
#  np.float64(0.5417953442294253),
#  np.float64(0.5422900053796166),
#  np.float64(0.542436023477523),
#  np.float64(0.5424744779502277),
#  np.float64(0.5421276507514473),
#  np.float64(0.5416342138966188),
#  np.float64(0.542671559897263),
#  np.float64(0.5440466632018076),
#  np.float64(0.544003752443752),
#  np.float64(0.5425375873982893),
#  np.float64(0.5420319193053893),
#  np.float64(0.5415252010205177),
#  np.float64(0.5435490069837546),
#  np.float64(0.5452157429633425),
#  np.float64(0.545376281842868),
#  np.float64(0.5442236211166429),
#  np.float64(0.543046492910584),
#  np.float64(0.5432351610070099),
#  np.float64(0.5457364581163267),
#  np.float64(0.5449176599698115),
#  np.float64(0.544932438426327),
#  np.float64(0.54403774380336),
#  np.float64(0.545147638458218),
#  np.float64(0.5447318528267777),
#  np.float64(0.5419081258020696),
#  np.float64(0.5440751581265775),
#  np.float64(0.5442583528355703),
#  np.float64(0.5438234198160299),
#  np.float64(0.547030686128637),
#  np.float64(0.5410583337954261),
#  np.float64(0.5437029824075545),
#  np.float64(0.5454269091633194),
#  np.float64(0.5427105077512177),
#  np.float64(0.5455779875558989),
#  np.float64(0.5455304211152008),
#  np.float64(0.5434495988982886),
#  np.float64(0.5452378140554663),
#  np.float64(0.5448190574597866),
#  np.float64(0.5460058468094358),
#  np.float64(0.5423198980101586),
#  np.float64(0.5444148845510317),
#  np.float64(0.5453137405998292),
#  np.float64(0.5460834241161381),
#  np.float64(0.5421790947239383),
#  np.float64(0.5440503938254103),
#  np.float64(0.5423726298637507),
#  np.float64(0.5455253156189176),
#  np.float64(0.5443586629013178),
#  np.float64(0.5436069066954551),
#  np.float64(0.5469319208502679),
#  np.float64(0.5423799988391751),
#  np.float64(0.5456001394332448),
#  np.float64(0.5437423341080573),
#  np.float64(0.5437781190030611),
#  np.float64(0.5434268549188749),
#  np.float64(0.5456570120334407),
#  np.float64(0.5445639263469279),
#  np.float64(0.5407148462076015),
#  np.float64(0.5406908074570054),
#  np.float64(0.5460534610572877),
#  np.float64(0.546214495897862),
#  np.float64(0.5421747675539763),
#  np.float64(0.5417187006448032),
#  np.float64(0.5429753837436687),
#  np.float64(0.5452869123924967),
#  np.float64(0.542244260834279),
#  np.float64(0.5422196793757902),
#  np.float64(0.5428660274866385),
#  np.float64(0.5430227319598232),
#  np.float64(0.5413426301219583),
#  np.float64(0.5450156203953122),
#  np.float64(0.5425529211602106),
#  np.float64(0.5425403647360201),
#  np.float64(0.5445858360748826),
#  np.float64(0.5465784026901354),
#  np.float64(0.5426842645107885),
#  np.float64(0.5452764072581071),
#  np.float64(0.5427010330597943),
#  np.float64(0.5421563277891533),
#  np.float64(0.5444014404655269),
#  np.float64(0.5426797237073014),
#  np.float64(0.5408830875732279),
#  np.float64(0.5447739466909545),
#  np.float64(0.544927888910495),
#  np.float64(0.5408332527575254),
#  np.float64(0.5393103242186514),
#  np.float64(0.5413991511207737),
#  np.float64(0.5397919140778078),
#  np.float64(0.5443864151674832),
#  np.float64(0.5449631307755284),
#  np.float64(0.5449505800773712),
#  np.float64(0.539763177431707),
#  np.float64(0.543388988143747),
#  np.float64(0.5417942501345652),
#  np.float64(0.5448440350604236),
#  np.float64(0.5414382698708037),
#  np.float64(0.5399807527170921),
#  np.float64(0.5409877095658565),
#  np.float64(0.5419845964102352),
#  np.float64(0.5413961626309206),
#  np.float64(0.5404033970949612),
#  np.float64(0.5451835648610855),
#  np.float64(0.5420355503408613),
#  np.float64(0.5429521692398926),
#  np.float64(0.5428918245166344),
#  np.float64(0.545573213073035),
#  np.float64(0.5422032901188973),
#  np.float64(0.5467375944398334),
#  np.float64(0.542668762719112),
#  np.float64(0.5411405020537604),
#  np.float64(0.540694171949206),
#  np.float64(0.5434057361799435),
#  np.float64(0.5443117286735935),
#  np.float64(0.5438100207694178),
#  np.float64(0.5453139870754933),
#  np.float64(0.5417317196236372),
#  np.float64(0.5414211608356202),
#  np.float64(0.54029388403216),
#  np.float64(0.5443145649034243),
#  np.float64(0.5418147320033179),
#  np.float64(0.5425133776941143),
#  np.float64(0.5403241272361848),
#  np.float64(0.5427933160413545),
#  np.float64(0.5429464674354628),
#  np.float64(0.5387103722600843),
#  np.float64(0.5436231851591173),
#  np.float64(0.5432653771958944),
#  np.float64(0.5432843255691878),
#  np.float64(0.5409854347816906),
#  np.float64(0.5428361126853987),
#  np.float64(0.5398179822635734),
#  np.float64(0.544231362115478),
#  np.float64(0.5402822774383927),
#  np.float64(0.5426227388866682),
#  np.float64(0.5436997099153119),
#  np.float64(0.5418835739756657),
#  np.float64(0.542805153233807),
#  np.float64(0.5430196198297498),
#  np.float64(0.544008319195706),
#  np.float64(0.5405157725090927),
#  np.float64(0.5435406925806825)]

# %%
# --- 绘制 RMSE vs. 特征数量图 ---
plt.figure(figsize=(12, 7), dpi=300)
plt.plot(range(len(rmse_scores)), rmse_scores, marker='o', linestyle='-', color='blue', markersize=5, label='RMSE')
plt.xlabel('Number of Selected Features', fontsize=14, weight='bold')
plt.ylabel('Validation RMSE(eV)', fontsize=14, weight='bold')
plt.title('RFE: RMSE vs. Number of Selected Features', fontsize=16, weight='bold')
plt.grid(True)

# 找到 RMSE 最小的点
best_n_features_index = np.argmin(rmse_scores)
best_n_features = best_n_features_index + 1  # +1 because index starts from 0
min_rmse = rmse_scores[best_n_features_index]

plt.axvline(x=best_n_features_index, color='red', linestyle='--', label=f'Best Feature Number: {best_n_features}')
plt.axhline(y=rmse_scores[best_n_features_index], color='red', linestyle='--')
plt.text(best_n_features_index + 1, rmse_scores[best_n_features_index] + 0.01,
         f'Best Feature Number: {best_n_features_index + 1}\nRMSE: {rmse_scores[best_n_features_index]:.4f}',
         fontsize=10, color='red', weight='bold')

plt.scatter(best_n_features, min_rmse, color='red', s=100, zorder=5,
            label=f'Min RMSE: {min_rmse:.4f}')
plt.legend(fontsize=10)
plt.tight_layout() # 调整布局防止标签重叠
fig_path = os.path.join(current_path, 'figures', 'feature_selection')
os.makedirs(fig_path, exist_ok=True)
plt.savefig(os.path.join(fig_path, 'RFE_feature_selection.png'), dpi=300)
plt.show()
print(f"\n根据验证集 RMSE，最佳的特征数量是: {best_n_features}")
print(f"对应的最小验证集 RMSE 是: {min_rmse:.4f}")
# Out:
# 根据验证集 RMSE，最佳的特征数量是: 64
# 对应的最小验证集 RMSE 是: 0.5383

# %%
best_n_features
# Out:
# np.int64(64)

# %%
# 获取最佳特征集的名称
estimator_final = RandomForestRegressor(
    n_estimators=500, max_depth=None, min_samples_split=2, min_samples_leaf=1,
    max_features=0.25, random_state=RANDOM_SEED, n_jobs=-1)

# 使用最佳特征数量重新训练模型
best_features = selected_features[best_n_features - 1]  # 获取最佳特征
X_train_best = dft_all_train_X.loc[:, best_features]
estimator_final.fit(X_train_best, dft_all_train_y)
# 输出特征重要性
importances = estimator_final.feature_importances_
indices = np.argsort(importances)[::-1]
# 获取特征名称
feature_names = X_train_best.columns[indices]
# 保存为 DataFrame
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances[indices]
})
# 保存特征重要性到 CSV 文件
save_dir = os.path.join(current_path, 'metrics', 'feature_importance', 'RFE')
os.makedirs(save_dir, exist_ok=True)
feature_importance_df.to_csv(os.path.join(save_dir, 'feature_importance.csv'), index=False)
# 保存rmse_scores
rmse_scores_df = pd.DataFrame({'RMSE': rmse_scores})
rmse_scores_df.to_csv(os.path.join(save_dir, 'rmse_scores.csv'), index=False)

# %%
# 绘制特征重要性图
from Utools.draw import plot_feature_importance
plot_feature_importance(estimator_final, X_train_best.columns, top_n=10,
                            fig_path=os.path.join(fig_path, f'feature_importance.png'))
# Out:
# Figure saved to: /workspaces/Bg_pre2/figures/feature_selection/feature_importance.png
#                            Feature  Importance
# 2                     mean Density    0.034149
# 5   minimum LogThermalConductivity    0.029692
# 1      minimum ThermalConductivity    0.028965
# 3      mode LogThermalConductivity    0.026667
# 6            mode HeatVaporization    0.025783
# 19       maximum Electronegativity    0.023368
# 8                    mean BoilingT    0.023224
# 0         mode ThermalConductivity    0.023077
# 4                    mean MeltingT    0.022205
# 7        range ThermalConductivity    0.020235

# %%
feature_importance_df.head(10)
# Out:
#                           Feature  Importance
# 0                    mean Density    0.034149
# 1  minimum LogThermalConductivity    0.029692
# 2     minimum ThermalConductivity    0.028965
# 3     mode LogThermalConductivity    0.026667
# 4           mode HeatVaporization    0.025783
# 5       maximum Electronegativity    0.023368
# 6                   mean BoilingT    0.023224
# 7        mode ThermalConductivity    0.023077
# 8                   mean MeltingT    0.022205
# 9       range ThermalConductivity    0.020235

# %%
selected_features[best_n_features - 1]
# Out:
# Index(['mode ThermalConductivity', 'minimum ThermalConductivity',
#        'mean Density', 'mode LogThermalConductivity', 'mean MeltingT',
#        'minimum LogThermalConductivity', 'mode HeatVaporization',
#        'range ThermalConductivity', 'mean BoilingT', 'minimum AtomicVolume',
#        'maximum Density', 'avg_dev GSenergy_pa', 'avg_dev ElectronAffinity',
#        'mean LogThermalConductivity', 'minimum MolarVolume',
#        'mean ZungerPP-r_sigma', 'mean ElectronAffinity',
#        'range LogThermalConductivity', 'avg_dev NValence',
#        'maximum Electronegativity', 'mean NpUnfilled', 'mean GSenergy_pa',
#        'range MeltingT', 'mean HeatVaporization', 'range HeatFusion',
#        'range HeatVaporization', 'avg_dev NUnfilled', 'maximum NfUnfilled',
#        'range AtomicVolume', 'range GSenergy_pa', 'mean Electronegativity',
#        'avg_dev FusionEnthalpy', 'mean HeatFusion',
#        'avg_dev FirstIonizationEnergy', 'avg_dev SpaceGroupNumber',
#        'avg_dev MeltingT', 'range Density', 'avg_dev Density',
#        'avg_dev Electronegativity', 'avg_dev Column',
#        'maximum ZungerPP-r_sigma', 'avg_dev ThermalConductivity',
#        'mean FusionEnthalpy', 'avg_dev NpValence', 'mean GSbandgap',
#        'avg_dev LogThermalConductivity', 'range ElectronAffinity',
#        'avg_dev NpUnfilled', 'mean AtomicVolume', 'mean NUnfilled',
#        'maximum NUnfilled', 'mean CovalentRadius', 'mean NdValence',
#        'mean GSestFCClatcnt', 'avg_dev NdValence', 'mean SpaceGroupNumber',
#        'avg_dev MolarVolume', 'mean AtomicWeight', 'range AtomicWeight',
#        'mean MolarVolume', 'avg_dev AtomicVolume', 'avg_dev GSestBCClatcnt',
#        'avg_dev AtomicWeight', 'minimum GSenergy_pa'],
#       dtype='object')

# %%
# 保存RFE后的训练集和测试集
train_dir = os.path.join(current_path, 'Data', 'rfe_train_data')
test_dir = os.path.join(current_path, 'Data', 'rfe_test_data')  
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

drop_columns = dft_train.columns[~dft_train.columns.isin(list(best_features)+['composition', 'band_gap'])]
dft_train_rfe = dft_train.drop(columns=drop_columns)
dft_test = pd.read_csv(os.path.join(file_dir, 'test_data', 'mp_test_set.csv'))
dft_test_rfe = dft_test.drop(columns=drop_columns)

# exp data
exp_train = pd.read_csv(os.path.join(file_dir, 'train_data', 'exp_train_set.csv'))
exp_test = pd.read_csv(os.path.join(file_dir, 'test_data', 'exp_test_set.csv'))
exp_train_rfe = exp_train.drop(columns=drop_columns)
exp_test_rfe = exp_test.drop(columns=drop_columns)
# mp plus data
mp_plus_train = pd.read_csv(os.path.join(file_dir, 'train_data', 'mp_plus_train_set.csv'))
mp_plus_test = pd.read_csv(os.path.join(file_dir, 'test_data', 'mp_plus_test_set.csv'))
mp_plus_train_rfe = mp_plus_train.drop(columns=drop_columns)
mp_plus_test_rfe = mp_plus_test.drop(columns=drop_columns)
# mix test 
mix_test = pd.read_csv(os.path.join(file_dir, 'test_data', 'mix_test_set.csv'))
mix_test_rfe = mix_test.drop(columns=drop_columns)


dft_train_rfe.to_csv(os.path.join(train_dir, 'mp_train_set.csv'), index=False)
dft_test_rfe.to_csv(os.path.join(test_dir, 'mp_test_set.csv'), index=False)
exp_train_rfe.to_csv(os.path.join(train_dir, 'exp_train_set.csv'), index=False) 
exp_test_rfe.to_csv(os.path.join(test_dir, 'exp_test_set.csv'), index=False)
mp_plus_train_rfe.to_csv(os.path.join(train_dir, 'mp_plus_train_set.csv'), index=False)
mp_plus_test_rfe.to_csv(os.path.join(test_dir, 'mp_plus_test_set.csv'), index=False)
mix_test_rfe.to_csv(os.path.join(test_dir, 'mix_test_set.csv'), index=False)

# %%
mp_plus_train_rfe.shape, mp_plus_test_rfe.shape
# Out:
# ((8275, 77), (2067, 77))

# %%
dft_train_rfe.shape, dft_test_rfe.shape
# Out:
# ((8275, 66), (2067, 66))

# %%
exp_train_rfe.shape, exp_test_rfe.shape
# Out:
# ((2545, 66), (585, 66))

# %%
mix_test_rfe.shape
# Out:
# (1170, 66)
